# %% [markdown]
# # Taller Introducción a la Programación en Python
# ## Ejercicios Clase 1

# %% [markdown]
# #### Ejercicio 1
# Este ejercicio simplemente busca repasar lo que aprendimos sobre definición de variables. Definí tres variables con un nombre combinado (al menos dos palabras):
# (a) Una siguiendo las buenas prácticas.
# (b) Hacer lo mismo de manera técnicamente correcta (sin error) pero sin seguir las buenas prácticas.
# (c) Intentar definir una variable con un nombre inacceptable (genera error).

# %%
# Caso A:
hola_mundo = "tp1"
print(hola_mundo)

# Caso B:
Hola_Mundo = "tp1"
print(Hola_Mundo)

# Caso C (acá abajo debería saltar un error):
#hola-mundo = "tp1"
#print(hola-mundo)
# Out:
# tp1
# tp1

# %% [markdown]
# #### Ejercicio 2
# Este ejercicio trata sobre la sustitución de variables y el uso de variables temporales para hacerlo. Las variables temporales y la sustitución de valores termina siendo útil en algunos loops. Los pasos a seguir son: (a) definir variables A y B (cuyos valores buscaremos invertir); (b) definir una variable temporal que hace de "memoria" y resguardo del valor; (c) sustitución (asignar B igual a A y también A a la variable temporal); (d) imprimir valores para verificar.

# %%
# Definir variables A y B:
a = 1
b = 2

# Definir variable temporal "tmp" igual a B (la variable, no el valor):
tmp = b

# Ahora sustituir variables:

# Variable B igual a variable A (la variable, no el valor):
b = a

# Variable A igual a variable "tmp":
a = tmp

# Verificar resultados, imprimir variables A y B:
print(a)
print(b)
# Out:
# 2
# 1

# %% [markdown]
# #### Ejercicio 3
# Pongamos en práctica el uso de range() en un for loop.
#
# Construir un for loop usando un range(). El range debe puede ser entre los valores que quieran (con una diferencia mínima de 15 entre start y stop), en incrementos de 3 unidades. Dentro del loop, implementar una sentencia condicional que imprimar una leyenda indicando si el input es par o impar.

# %%
# Construyo un for loop usando range()

for numero in range(0,16,3):
    if numero % 2 == 0:
        print(numero, "es par")
    else:
        print(numero, "es impar")
# Out:
# 0 es par
# 3 es impar
# 6 es par
# 9 es impar
# 12 es par
# 15 es impar

# %% [markdown]
# #### Ejercicio 4
# Para practicar el uso de condiciones lógicas, construyamos una sentencia condicional que verifique si un año es bisiesto o no. Para que un año sea bisiesto debe cumplir una de dos condiciones:
# (a) sea divisible por 400 OR
# (b) sea divisible por 4 AND no sea divisible por 100
#
# Nótese que son dos condiciones, dónde la segunda condición tiene dos componentes. Prueben la sentencia con una serie de valores para verificar que funcione.

# %%
# Construyo un for loop utilizando una sentencia condicional

for anio in range(2010,2023):
    if anio % 400 == 0 or (anio % 4 == 0 and anio % 100 != 0):
        print(anio, "es bisiesto")
    else:
        print(anio, "no es bisiesto")
# Out:
# 2010 no es bisiesto
# 2011 no es bisiesto
# 2012 es bisiesto
# 2013 no es bisiesto
# 2014 no es bisiesto
# 2015 no es bisiesto
# 2016 es bisiesto
# 2017 no es bisiesto
# 2018 no es bisiesto
# 2019 no es bisiesto
# 2020 es bisiesto
# 2021 no es bisiesto
# 2022 no es bisiesto

# %% [markdown]
# #### Ejercicio 5
# Pongamos en práctica identificar el type() de cada variable. A continuación tenemos una lista con elementos de diferentes tipos. Construyan un for loop que itere sobre la lista e imprima un cartel indicando el tipo de dato que hay en cada caso.

# %%
# Construyo un for loop que itera sobre una lista

mi_lista = [1, 3.4, 5666666666, "hola", [1,2,3], ('ARG', 45808747), {'pob_arg': 45808747}, True]

for i in mi_lista:
    print("El elemento", i, "es", type(i))
# Out:
# El elemento 1 es <class 'int'>
# El elemento 3.4 es <class 'float'>
# El elemento 5666666666 es <class 'int'>
# El elemento hola es <class 'str'>
# El elemento [1, 2, 3] es <class 'list'>
# El elemento ('ARG', 45808747) es <class 'tuple'>
# El elemento {'pob_arg': 45808747} es <class 'dict'>
# El elemento True es <class 'bool'>

# %% [markdown]
# #### Ejercicio 6
# Ahora definan ustedes una lista, en la que los primeros 4 elementos sean palabras (strings) la 5ta no sea string, y la 6ta sea string. Construyan un for loop que corra por la lista y que imprima la palabra y la longitud de la misma. Que el loop contenga una sentencia condicional que imprima un cartel "Elemento no es un string: < el elemento > | < class del elemento >" para los casos dónde el elemento evaluado no sea string.
#
# _Comentario: más adelante vamos a aprender como manejar errores._

# %%
# Construyo un foor loop que itera sobre una lista

lista = ["hola", "como", "estas", "todo", 10, "bien"]

for i in lista:
    if type(i) == str:
        print("Elemento:", i, "---", "Longitud:", len(i))
    else:
        print("Elemento no es un string:", i, type(i))
# Out:
# Elemento: hola --- Longitud: 4
# Elemento: como --- Longitud: 4
# Elemento: estas --- Longitud: 5
# Elemento: todo --- Longitud: 4
# Elemento no es un string: 10 <class 'int'>
# Elemento: bien --- Longitud: 4

# %% [markdown]
# #### Ejercicio 7
#
# Ahora probemos algo con un nivel más de dificultad. Argentina tiene una representación legislativa proporcional en la cual la cantidad de diputados se debería ajustar según el tamaño de población de cada provincia. Otra característica de la representación legislativa del país es que hay una cantidad mínima de diputados por provincia (5). Esto genera un desbalance en la cantidad de ciudadanos por cada representante en el Congreso entre provincias.
#
# A continuación les dejamos la cantidad de bancas y la población de algunas provincias (según estimación para el 2021) y del agregado a nivel país.
#
# En este ejercicio les pedimos que primero construyan un diccionario para cada provincia que contenga 3 llaves: nombre de la provincia, población y bancas. Luego creen otro conjunto que contenga los diccionarios de las 5 provincias. Finalmente deben crear un loop que itere sobre el conjunto creado y calcule para cada provincia la proporción de población por bancas, a su vez, el loop debe hacer dos tareas con dicha proporción:
#
# - debe comparar cada proporción provincial contra el valor de proporcionalidad directa (la poblacion argentina sobre las bancas de todo el país). El loop debe imprimir una leyenda que indique: (a) nombre de la jurisdicción, (b) cantidad de bancas y (c) si la provincia está sobrerepresentada, subrepresentada o con representación proporcional. Por ejemplo la leyenda podría decir: "La provincia (a) tiene (b) bancas, lo que significa que está (c) con su cantidad de diputados". Esta leyenda se deberá imprimir tantas veces como provincias en su conjunto.
#
# - debe distinguir la _proporción de población por bancas_ de las provincias sobrerepresentadas y guardar el valor de la provincia con mayor sobrerepresentación. Una vez terminado el loop, impriman la leyenda: "La provincia con mayor sobrerepresentación es (a)" Esta leyenda se deberá imprimir una sola vez.
#
# _Ayuda: el ejercicio 2 les puede ayudar para resolver parte de este problema._
#
#
# Fuente para población: https://es.wikipedia.org/wiki/Demograf%C3%ADa_de_Argentina
#
# Fuente para representantes: https://es.wikipedia.org/wiki/C%C3%A1mara_de_Diputados_de_la_Naci%C3%B3n_Argentina

# %%
# La proporción se calcula haciendo: población / bancas en el Congreso.

# Variables con la población y las bancas a nivel nacional:

argentina_poblacion = 47327407
argentina_bancas = 257

# Variables con la población y las bancas para una selección de jurisdicciones:

catamarca_poblacion = 367820
catamarca_bancas = 5

buenos_aires_poblacion = 17594428
buenos_aires_bancas = 70

misiones_poblacion = 1097829
misiones_bancas = 7

tierra_fuego_poblacion = 126190
tierra_fuego_bancas = 5

tucuman_poblacion = 1950878
tucuman_bancas = 9

# %%
# Defino diccionarios
dic_catamarca = {'nombre de la provincia':"Catamarca", 'poblacion':catamarca_poblacion, 'bancas':catamarca_bancas}
dic_buenos_aires = {'nombre de la provincia':"Buenos Aires", 'poblacion':buenos_aires_poblacion, 'bancas':buenos_aires_bancas}
dic_misiones = {'nombre de la provincia':"Misiones", 'poblacion':misiones_poblacion, 'bancas':misiones_bancas}
dic_tierra_fuego = {'nombre de la provincia':"Tierra del Fuego", 'poblacion':tierra_fuego_poblacion, 'bancas':tierra_fuego_bancas}
dic_tucuman = {'nombre de la provincia':"Tucumán", 'poblacion':tucuman_poblacion, 'bancas':tucuman_bancas}
lista_provincias = [dic_catamarca, dic_buenos_aires, dic_misiones, dic_tierra_fuego, dic_tucuman]

print("Diccionario Catamarca:", dic_catamarca)
print("Diccionario Buenos Aires:", dic_buenos_aires)
print("Diccionario Misiones:", dic_misiones)
print("Diccionario Tierra del Fuego:", dic_tierra_fuego)
print("Diccionario Tucumán:", dic_tucuman)
print("Lista con diccionarios de provincias:", lista_provincias)

# Defino valor de proporcionalidad directa
shr_pop_argentina = argentina_poblacion/argentina_bancas
print("Valor de proporcionalidad directa:", shr_pop_argentina)

# Defino variable shr_max (mínimo valor de sobrerepresentación)
shr_max = shr_pop_argentina

# Creo un for loop que itera sobre el conjunto creado

for provincia in lista_provincias:

    shr_pop = provincia["poblacion"] / provincia["bancas"]

    if shr_pop < shr_pop_argentina:
        definicion = "sobrerepresentada"
        if shr_pop < shr_max:
            nombre_max = provincia['nombre de la provincia']
            shr_max = shr_pop

    elif shr_pop > shr_pop_argentina:
        definicion = "subrepresentada"

    else:
        definicion = "con representación proporcional"

    print("La provincia", provincia["nombre de la provincia"], "tiene", provincia["bancas"], "bancas, lo que implica que está", definicion, "con su cantidad de diputados")

print("La provincia con mayor sobrerepresentación es", nombre_max, "con una representación de", shr_max, "habitantes por banca")
# Out:
# Diccionario Catamarca: {'nombre de la provincia': 'Catamarca', 'poblacion': 367820, 'bancas': 5}
# Diccionario Buenos Aires: {'nombre de la provincia': 'Buenos Aires', 'poblacion': 17594428, 'bancas': 70}
# Diccionario Misiones: {'nombre de la provincia': 'Misiones', 'poblacion': 1097829, 'bancas': 7}
# Diccionario Tierra del Fuego: {'nombre de la provincia': 'Tierra del Fuego', 'poblacion': 126190, 'bancas': 5}
# Diccionario Tucumán: {'nombre de la provincia': 'Tucumán', 'poblacion': 1950878, 'bancas': 9}
# Lista con diccionarios de provincias: [{'nombre de la provincia': 'Catamarca', 'poblacion': 367820, 'bancas': 5}, {'nombre de la provincia': 'Buenos Aires', 'poblacion': 17594428, 'bancas': 70}, {'nombre de la provincia': 'Misiones', 'poblacion': 1097829, 'bancas': 7}, {'nombre de la provincia': 'Tierra del Fuego', 'poblacion': 126190, 'bancas': 5}, {'nombre de la provincia': 'Tucumán', 'poblacion': 1950878, 'bancas': 9}]
# Valor de proporcionalidad directa: 184153.3346303502
# La provincia Catamarca tiene 5 bancas, lo que implica que está sobrerepresentada con su cantidad de diputados
# La provincia Buenos Aires tiene 70 bancas, lo que implica que está subrepresentada con su cantidad de diputados
# La provincia Misiones tiene 7 bancas, lo que implica que está sobrerepresentada con su cantidad de diputados
# La provincia Tierra del Fuego tiene 5 bancas, lo que implica que está sobrerepresentada con su cantidad de diputados
# La provincia Tucumán tiene 9 bancas, lo que implica que está subrepresentada con su cantidad de diputados
# La provincia con mayor sobrerepresentación es Tierra del Fuego con una representación de 25238.0 habitantes por banca

# %% [markdown]
# #### Ejercicio 8
# Excelente! Un último ejercicio. Si buscáramos minimizar la subrepresentación de la provincia de Buenos Aires, ¿cuántos representantes debería tener según el Censo 2022? Usemos el mismo criterio de sub/sobrerepresentacion que en el ejercicio anterior: población sobre cantidad de representantes.
#
# Para responder esta pregunta construyan un while loop que incremente de a uno la cantidad de representantes de la Provincia hasta minimizar la subrepresentación (sin pasar el límite de la proporción directa, lo cual implicaría una sobrerepresentación). En cada iteración impriman un cartel que diga: "Se agregó un represntante, el total ahora es X" dónde X es el número de representantes simulado. Luego de correr el loop escriban su respuesta final. Su respuesta final debiera ser el número de representantes que minimza la subrepresentación.

# %%
# Estos son los valores de la provincia de Buenos Aires:
representantes_pba = 70
poblacion2010_pba = 17594428

# Y éste es el valor de referencia nacional:
argentina = 47327407 / 257

# %%
# Defino variables
representantes_pba_obj = representantes_pba
shr_pop_pba = poblacion2010_pba / representantes_pba

# Construyo un while loop

while shr_pop_pba > argentina:
    representantes_pba_obj += 1
    print("Se agregó un representante, el total ahora es", representantes_pba_obj)
    shr_pop_pba = poblacion2010_pba / representantes_pba_obj
    if shr_pop_pba <= argentina:
        representantes_pba_obj -= 1
        break

print("El número de representantes que minimiza la subrepresentación es", representantes_pba_obj)
# Out:
# Se agregó un representante, el total ahora es 71
# Se agregó un representante, el total ahora es 72
# Se agregó un representante, el total ahora es 73
# Se agregó un representante, el total ahora es 74
# Se agregó un representante, el total ahora es 75
# Se agregó un representante, el total ahora es 76
# Se agregó un representante, el total ahora es 77
# Se agregó un representante, el total ahora es 78
# Se agregó un representante, el total ahora es 79
# Se agregó un representante, el total ahora es 80
# Se agregó un representante, el total ahora es 81
# Se agregó un representante, el total ahora es 82
# Se agregó un representante, el total ahora es 83
# Se agregó un representante, el total ahora es 84
# Se agregó un representante, el total ahora es 85
# Se agregó un representante, el total ahora es 86
# Se agregó un representante, el total ahora es 87
# Se agregó un representante, el total ahora es 88
# Se agregó un representante, el total ahora es 89
# Se agregó un representante, el total ahora es 90
# Se agregó un representante, el total ahora es 91
# Se agregó un representante, el total ahora es 92
# Se agregó un representante, el total ahora es 93
# Se agregó un representante, el total ahora es 94
# Se agregó un representante, el total ahora es 95
# Se agregó un representante, el total ahora es 96
# El número de representantes que minimiza la subrepresentación es 95
